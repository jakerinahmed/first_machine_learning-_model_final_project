# %% [markdown]
# <a href="https://colab.research.google.com/github/bradneve/first_data/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import csv
import pandas as pd
from numpy import nan
import seaborn as sns
import aiohttp
import nest_asyncio
import asyncio
from fpl import FPL
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
# pip install fpl

# %%
pip install nest-asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (1.5.6)

# %%
# async def main():
#     async with aiohttp.ClientSession() as session:
#         fpl = FPL(session)
#         player = await fpl.get_player(629)
#     print(player)

# nest_asyncio.apply()
# asyncio.run(main())

# %%
name_response = requests.get("https://fantasy.premierleague.com/api/bootstrap-static/")
names = name_response.json()["elements"]

# %%
games_data = []
for i in range(1, 629):
  for x in names:
    if x["id"] == i:
      boostrap_player_data = x
  response = requests.get(f"https://fantasy.premierleague.com/api/element-summary/{i}/")
  player_games_data = response.json()
  prev_game = {"summed_ict": 0, "ict_index": 0, "minutes": 0, "total_mins": 0, "total_goals": 0, "goals_scored": 0, "goals_conceded": 0, "total_goals_conceded": 0, "total_assists": 0, "assists": 0}
  for x in player_games_data["history"]:
    x["position"] = boostrap_player_data["element_type"]
    if prev_game["total_mins"] == 0 :
      x["ict_index"] = float(x["ict_index"])
      x["summed_ict"] = prev_game["summed_ict"] + prev_game["ict_index"]
      x["total_mins"] = prev_game["minutes"] + prev_game["total_mins"]
      x["total_goals"] = prev_game["goals_scored"] + prev_game["total_goals"]
      x["total_goals_conceded"] = prev_game["goals_conceded"] + prev_game["total_goals_conceded"]
      x["total_assists"] = prev_game["assists"] + prev_game["total_assists"]
      x["average_ict_per_90"] = prev_game["summed_ict"]
      x["average_goals_per_90"] = prev_game["total_goals"]
      x["average_goals_conceded_per_90"] = prev_game["total_goals_conceded"]
      x["average_assists_per_90"] = prev_game["total_assists"]
      games_data.append(x)
      prev_game = x
    else:
      x["ict_index"] = float(x["ict_index"])
      x["summed_ict"] = prev_game["summed_ict"] + prev_game["ict_index"]
      x["total_mins"] = prev_game["minutes"] + prev_game["total_mins"]
      x["total_goals"] = prev_game["goals_scored"] + prev_game["total_goals"]
      x["total_assists"] = prev_game["assists"] + prev_game["total_assists"]
      x["total_goals_conceded"] = prev_game["goals_conceded"] + prev_game["total_goals_conceded"]
      x["average_ict_per_90"] = 90*prev_game["summed_ict"]/prev_game["total_mins"]
      x["average_goals_per_90"] = 90*prev_game["total_goals"]/prev_game["total_mins"]
      x["average_goals_conceded_per_90"] = 90*prev_game["total_goals_conceded"]/prev_game["total_mins"]
      x["average_assists_per_90"] = 90*prev_game["total_assists"]/prev_game["total_mins"]
      games_data.append(x)
      prev_game = x
    



# print(games_data)

# %%
def select_data(player):
    return {
        "total_points": player["total_points"],
        "position": player["position"],
        "was_home": player["was_home"],
        "opponent_team": player["opponent_team"],
        "average_goals_per_90": player["average_goals_per_90"],
        "average_assists_per_90": player["average_assists_per_90"],
        "average_ict_per_90": player["average_ict_per_90"],
        "average_goals_conceded_per_90": player["average_goals_conceded_per_90"],
    }

for i in range(len(games_data)):
  games_data[i] = select_data(games_data[i])

print(games_data)
# Out:
_per_90': 3.650000000000001, 'average_goals_conceded_per_90': 2.0}, {'total_points': 1, 'position': 1, 'was_home': False, 'opponent_team': 16, 'average_goals_per_90': 0.0, 'average_assists_per_90': 0.0, 'average_ict_per_90': 3.4000000000000004, 'average_goals_conceded_per_90': 1.6666666666666667}, {'total_points': 2, 'position': 1, 'was_home': True, 'opponent_team': 15, 'average_goals_per_90': 0.0, 'average_assists_per_90': 0.0, 'average_ict_per_90': 4.0, 'average_goals_conceded_per_90': 1.75}, {'total_points': 2, 'position': 1, 'was_home': False, 'opponent_team': 19, 'average_goals_per_90': 0.0, 'average_assists_per_90': 0.0, 'average_ict_per_90': 3.36, 'average_goals_conceded_per_90': 1.8}, {'total_points': 2, 'position': 1, 'was_home': T ...

# %%
headers = ['total_points', "position", 'was_home', 'opponent_team', 'average_goals_per_90', "average_assists_per_90", "average_ict_per_90", "average_goals_conceded_per_90"]

with open("player_data.csv", "w", newline='') as file:
    f = csv.writer(file)
    f.writerow(headers)
    for p in games_data:
        values = [p[h] for h in headers]
        f.writerow(values)

# %%
player_data = pd.read_csv('player_data.csv')

# %%
player_data.columns
# Out:
# Index(['total_points', 'position', 'was_home', 'opponent_team',
#        'average_goals_per_90', 'average_assists_per_90', 'average_ict_per_90',
#        'average_goals_conceded_per_90'],
#       dtype='object')

# %%
y = player_data["total_points"]

X = player_data[['position', 'was_home', 'opponent_team', 'average_goals_per_90',
       'average_assists_per_90', 'average_ict_per_90', 'average_goals_conceded_per_90']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=500)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.5350803043110736

# %%
plt.figure(figsize=(25, 13))

plot_tree(model, filled=True, rounded=True, feature_names=X.columns, class_names=model.classes_);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-44416a581488> in <module>
#       1 plt.figure(figsize=(25, 13))
#       2
# ----> 3 plot_tree(model, filled=True, rounded=True, feature_names=X.columns, class_names=model.classes_);
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     193         fontsize=fontsize,
#     194     )
# --> 195     return exporter.export(decision_tree, ax=ax)
#     196
#     197
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     654         ax.clear()
#     655         ax.set_axis_off()
# --> 656         my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     657         draw_tree = buchheim(my_tree)
#     658
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_export.py in _make_tree(self, node_id, et, criterion, depth)
#     630         # traverses _tree.Tree recursively, builds intermediate
#     631         # "_reingold_tilford.Tree" object
# --> 632         name = self.node_to_str(et, node_id, criterion=criterion)
#     633         if et.children_left[node_id] != _tree.TREE_LEAF and (
#     634             self.max_depth is None or depth <= self.max_depth
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_export.py in node_to_str(self, tree, node_id, criterion)
#     372                     characters[2],
#     373                 )
# --> 374             node_string += class_name
#     375
#     376         # Clean up any trailing newlines
#
# TypeError: can only concatenate str (not "numpy.int64") to str
